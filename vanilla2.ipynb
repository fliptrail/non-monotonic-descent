# %%
# %matplotlib inline
import numpy as np
import tensorflow as tf
from d2l import tensorflow as d2l
from enum import Enum

# %%
def show_trace(results, f, function_string, lr):
    n = max(abs(min(results)), abs(max(results)))
    f_line = tf.range(-n, n, 0.01)
    d2l.set_figsize()
    d2l.plot([f_line, results],
             [[f(x) for x in f_line], [f(x) for x in results]], f"x with learning rate {lr}", f"f(x) = {function_string}",
             fmts=['-', '-o'])

# %%
def f(x):  # Objective function
    return 10 * (x**2)

def f_grad(x):  # Gradient (derivative) of the objective function
    return 20 * x

# %%
def gd(eta, f_grad, epochs):
    x = 5.0
    results = [x]
    for i in range(epochs):
        x -= eta * f_grad(x)
        results.append(float(x))
    print(f'epoch {epochs}, x: {x:f}')
    return results

# %%
def my_gd(eta, f_grad, epochs):
    x = 5.0
    results = [x]
    for i in range(epochs):
        x -= (abs(f_grad(x)) * abs(f_grad(x)) * f_grad(x)) / ((1 + f_grad(x)**2)**2)
        results.append(float(x))
        print(f'epoch {i}, x: {x:f}')
    print(f'epoch {epochs}, x: {x:f}')
    return results

# %%
show_trace(gd(0.12, f_grad, 10), f, "10x^2", 0.12)
# Out:
# epoch 10, x: 144.627327

# %%
show_trace(gd(0.02, f_grad, 10), f, "x^2", 0.02)
# Out:
# epoch 10, x: 0.030233

# %%
show_trace(my_gd(1, f_grad, 1000), f, "x^2", 3)
# Out:
# epoch 0, x: 4.990002
# epoch 1, x: 4.979984
# epoch 2, x: 4.969946
# epoch 3, x: 4.959887
# epoch 4, x: 4.949809
# epoch 5, x: 4.939709
# epoch 6, x: 4.929589
# epoch 7, x: 4.919448
# epoch 8, x: 4.909287
# epoch 9, x: 4.899104
# epoch 10, x: 4.888900
# epoch 11, x: 4.878675
# epoch 12, x: 4.868429
# epoch 13, x: 4.858161
# epoch 14, x: 4.847871
# epoch 15, x: 4.837559
# epoch 16, x: 4.827226
# epoch 17, x: 4.816870
# epoch 18, x: 4.806492
# epoch 19, x: 4.796092
# epoch 20, x: 4.785669
# epoch 21, x: 4.775223
# epoch 22, x: 4.764755
# epoch 23, x: 4.754263
# epoch 24, x: 4.743749
# epoch 25, x: 4.733211
# epoch 26, x: 4.722650
# epoch 27, x: 4.712065
# epoch 28, x: 4.701456
# epoch 29, x: 4.690823
# epoch 30, x: 4.680167
# epoch 31, x: 4.669486
# epoch 32, x: 4.658781
# epoch 33, x: 4.648051
# epoch 34, x: 4.637296
# epoch 35, x: 4.626516
# epoch 36, x: 4.615711
# epoch 37, x: 4.604881
# epoch 38, x: 4.594026
# epoch 39, x: 4.583145
# epoch 40, x: 4.572238
# epoch 41, x: 4.561305
# epoch 42, x: 4.550346
# epoch 43, x: 4.539360
# epoch 44, x: 4.528348
# epoch 45, x: 4.517309
# epoch 46, x: 4.506243
# epoch 47, x: 4.495151
# epoch 48, x: 4.484030
# epoch 49, x: 4.472882
# epoch 50, x: 4.461707
# epoch 51, x: 4.450503
# epoch 52, x: 4.439271
# epoch 53, x: 4.428011
# epoch 54, x: 4.416722
# epoch 55, x: 4.405404
# epoch 56, x: 4.394057
# epoch 57, x: 4.382681
# epoch 58, x: 4.371276
# epoch 59, x: 4.359841
# epoch 60, x: 4.348375
# epoch 61, x: 4.336880
# epoch 62, x: 4.325354
# epoch 63, x: 4.313797
# epoch 64, x: 4.302209
# epoch 65, x: 4.290591
# epoch 66, x: 4.278940
# epoch 67, x: 4.267258
# epoch 68, x: 4.255545
# epoch 69, x: 4.243798
# epoch 70, x: 4.232020
# epoch 71, x: 4.220208
# epoch 72, x: 4.208364
# epoch 73, x: 4.196486
# epoch 74, x: 4.184575
# epoch 75, x: 4.172630
# epoch 76, x: 4.160650
# epoch 77, x: 4.148636
# epoch 78, x: 4.136588
# epoch 79, x: 4.124504
# epoch 80, x: 4.112385
# epoch 81, x: 4.100230
# epoch 82, x: 4.088039
# epoch 83, x: 4.075812
# epoch 84, x: 4.063548
# epoch 85, x: 4.051248
# epoch 86, x: 4.038909
# epoch 87, x: 4.026534
# epoch 88, x: 4.014120
# epoch 89, x: 4.001668
# epoch 90, x: 3.989177
# epoch 91, x: 3.976647
# epoch 92, x: 3.964077
# epoch 93, x: 3.951468
# epoch 94, x: 3.938819
# epoch 95, x: 3.926129
# epoch 96, x: 3.913398
# epoch 97, x: 3.900625
# epoch 98, x: 3.887811
# epoch 99, x: 3.874954
# epoch 100, x: 3.862055
# epoch 101, x: 3.849113
# epoch 102, x: 3.836128
# epoch 103, x: 3.823098
# epoch 104, x: 3.810024
# epoch 105, x: 3.796905
# epoch 106, x: 3.783741
# epoch 107, x: 3.770531
# epoch 108, x: 3.757275
# epoch 109, x: 3.743973
# epoch 110, x: 3.730622
# epoch 111, x: 3.717225
# epoch 112, x: 3.703779
# epoch 113, x: 3.690284
# epoch 114, x: 3.676740
# epoch 115, x: 3.663146
# epoch 116, x: 3.649501
# epoch 117, x: 3.635806
# epoch 118, x: 3.622059
# epoch 119, x: 3.608260
# epoch 120, x: 3.594408
# epoch 121, x: 3.580503
# epoch 122, x: 3.566544
# epoch 123, x: 3.552530
# epoch 124, x: 3.538462
# epoch 125, x: 3.524337
# epoch 126, x: 3.510155
# epoch 127, x: 3.495917
# epoch 128, x: 3.481620
# epoch 129, x: 3.467265
# epoch 130, x: 3.452850
# epoch 131, x: 3.438376
# epoch 132, x: 3.423840
# epoch 133, x: 3.409243
# epoch 134, x: 3.394583
# epoch 135, x: 3.379860
# epoch 136, x: 3.365073
# epoch 137, x: 3.350221
# epoch 138, x: 3.335303
# epoch 139, x: 3.320319
# epoch 140, x: 3.305267
# epoch 141, x: 3.290147
# epoch 142, x: 3.274957
# epoch 143, x: 3.259697
# epoch 144, x: 3.244365
# epoch 145, x: 3.228961
# epoch 146, x: 3.213483
# epoch 147, x: 3.197932
# epoch 148, x: 3.182304
# epoch 149, x: 3.166600
# epoch 150, x: 3.150818
# epoch 151, x: 3.134957
# epoch 152, x: 3.119016
# epoch 153, x: 3.102994
# epoch 154, x: 3.086888
# epoch 155, x: 3.070699
# epoch 156, x: 3.054425
# epoch 157, x: 3.038064
# epoch 158, x: 3.021615
# epoch 159, x: 3.005077
# epoch 160, x: 2.988448
# epoch 161, x: 2.971726
# epoch 162, x: 2.954910
# epoch 163, x: 2.937999
# epoch 164, x: 2.920990
# epoch 165, x: 2.903883
# epoch 166, x: 2.886675
# epoch 167, x: 2.869364
# epoch 168, x: 2.851949
# epoch 169, x: 2.834428
# epoch 170, x: 2.816799
# epoch 171, x: 2.799059
# epoch 172, x: 2.781208
# epoch 173, x: 2.763241
# epoch 174, x: 2.745159
# epoch 175, x: 2.726957
# epoch 176, x: 2.708634
# epoch 177, x: 2.690187
# epoch 178, x: 2.671614
# epoch 179, x: 2.652911
# epoch 180, x: 2.634077
# epoch 181, x: 2.615109
# epoch 182, x: 2.596004
# epoch 183, x: 2.576757
# epoch 184, x: 2.557368
# epoch 185, x: 2.537831
# epoch 186, x: 2.518145
# epoch 187, x: 2.498305
# epoch 188, x: 2.478307
# epoch 189, x: 2.458148
# epoch 190, x: 2.437825
# epoch 191, x: 2.417332
# epoch 192, x: 2.396666
# epoch 193, x: 2.375821
# epoch 194, x: 2.354795
# epoch 195, x: 2.333581
# epoch 196, x: 2.312174
# epoch 197, x: 2.290569
# epoch 198, x: 2.268762
# epoch 199, x: 2.246744
# epoch 200, x: 2.224512
# epoch 201, x: 2.202058
# epoch 202, x: 2.179375
# epoch 203, x: 2.156457
# epoch 204, x: 2.133296
# epoch 205, x: 2.109884
# epoch 206, x: 2.086212
# epoch 207, x: 2.062273
# epoch 208, x: 2.038056
# epoch 209, x: 2.013553
# epoch 210, x: 1.988751
# epoch 211, x: 1.963642
# epoch 212, x: 1.938212
# epoch 213, x: 1.912449
# epoch 214, x: 1.886340
# epoch 215, x: 1.859871
# epoch 216, x: 1.833027
# epoch 217, x: 1.805790
# epoch 218, x: 1.778143
# epoch 219, x: 1.750069
# epoch 220, x: 1.721545
# epoch 221, x: 1.692550
# epoch 222, x: 1.663060
# epoch 223, x: 1.633050
# epoch 224, x: 1.602489
# epoch 225, x: 1.571349
# epoch 226, x: 1.539593
# epoch 227, x: 1.507186
# epoch 228, x: 1.474084
# epoch 229, x: 1.440243
# epoch 230, x: 1.405610
# epoch 231, x: 1.370128
# epoch 232, x: 1.333732
# epoch 233, x: 1.296348
# epoch 234, x: 1.257893
# epoch 235, x: 1.218269
# epoch 236, x: 1.177365
# epoch 237, x: 1.135050
# epoch 238, x: 1.091170
# epoch 239, x: 1.045539
# epoch 240, x: 0.997935
# epoch 241, x: 0.948082
# epoch 242, x: 0.895636
# epoch 243, x: 0.840156
# epoch 244, x: 0.781063
# epoch 245, x: 0.717569
# epoch 246, x: 0.648561
# epoch 247, x: 0.572376
# epoch 248, x: 0.486339
# epoch 249, x: 0.385669
# epoch 250, x: 0.260275
# epoch 251, x: 0.081601
# epoch 252, x: -0.242281
# epoch 253, x: -0.052425
# epoch 254, x: 0.209113
# epoch 255, x: -0.004831
# epoch 256, x: -0.003945
# epoch 257, x: -0.003460
# epoch 258, x: -0.003132
# epoch 259, x: -0.002888
# epoch 260, x: -0.002697
# epoch 261, x: -0.002541
# epoch 262, x: -0.002410
# epoch 263, x: -0.002299
# epoch 264, x: -0.002202
# epoch 265, x: -0.002117
# epoch 266, x: -0.002041
# epoch 267, x: -0.001973
# epoch 268, x: -0.001912
# epoch 269, x: -0.001856
# epoch 270, x: -0.001805
# epoch 271, x: -0.001758
# epoch 272, x: -0.001715
# epoch 273, x: -0.001675
# epoch 274, x: -0.001637
# epoch 275, x: -0.001602
# epoch 276, x: -0.001569
# epoch 277, x: -0.001538
# epoch 278, x: -0.001509
# epoch 279, x: -0.001482
# epoch 280, x: -0.001456
# epoch 281, x: -0.001431
# epoch 282, x: -0.001408
# epoch 283, x: -0.001386
# epoch 284, x: -0.001364
# epoch 285, x: -0.001344
# epoch 286, x: -0.001325
# epoch 287, x: -0.001306
# epoch 288, x: -0.001288
# epoch 289, x: -0.001271
# epoch 290, x: -0.001255
# epoch 291, x: -0.001239
# epoch 292, x: -0.001224
# epoch 293, x: -0.001209
# epoch 294, x: -0.001195
# epoch 295, x: -0.001181
# epoch 296, x: -0.001168
# epoch 297, x: -0.001155
# epoch 298, x: -0.001143
# epoch 299, x: -0.001131
# epoch 300, x: -0.001120
# epoch 301, x: -0.001108
# epoch 302, x: -0.001098
# epoch 303, x: -0.001087
# epoch 304, x: -0.001077
# epoch 305, x: -0.001067
# epoch 306, x: -0.001057
# epoch 307, x: -0.001048
# epoch 308, x: -0.001038
# epoch 309, x: -0.001029
# epoch 310, x: -0.001021
# epoch 311, x: -0.001012
# epoch 312, x: -0.001004
# epoch 313, x: -0.000996
# epoch 314, x: -0.000988
# epoch 315, x: -0.000980
# epoch 316, x: -0.000973
# epoch 317, x: -0.000965
# epoch 318, x: -0.000958
# epoch 319, x: -0.000951
# epoch 320, x: -0.000944
# epoch 321, x: -0.000938
# epoch 322, x: -0.000931
# epoch 323, x: -0.000924
# epoch 324, x: -0.000918
# epoch 325, x: -0.000912
# epoch 326, x: -0.000906
# epoch 327, x: -0.000900
# epoch 328, x: -0.000894
# epoch 329, x: -0.000888
# epoch 330, x: -0.000883
# epoch 331, x: -0.000877
# epoch 332, x: -0.000872
# epoch 333, x: -0.000867
# epoch 334, x: -0.000861
# epoch 335, x: -0.000856
# epoch 336, x: -0.000851
# epoch 337, x: -0.000846
# epoch 338, x: -0.000842
# epoch 339, x: -0.000837
# epoch 340, x: -0.000832
# epoch 341, x: -0.000827
# epoch 342, x: -0.000823
# epoch 343, x: -0.000818
# epoch 344, x: -0.000814
# epoch 345, x: -0.000810
# epoch 346, x: -0.000806
# epoch 347, x: -0.000801
# epoch 348, x: -0.000797
# epoch 349, x: -0.000793
# epoch 350, x: -0.000789
# epoch 351, x: -0.000785
# epoch 352, x: -0.000781
# epoch 353, x: -0.000778
# epoch 354, x: -0.000774
# epoch 355, x: -0.000770
# epoch 356, x: -0.000766
# epoch 357, x: -0.000763
# epoch 358, x: -0.000759
# epoch 359, x: -0.000756
# epoch 360, x: -0.000752
# epoch 361, x: -0.000749
# epoch 362, x: -0.000746
# epoch 363, x: -0.000742
# epoch 364, x: -0.000739
# epoch 365, x: -0.000736
# epoch 366, x: -0.000733
# epoch 367, x: -0.000729
# epoch 368, x: -0.000726
# epoch 369, x: -0.000723
# epoch 370, x: -0.000720
# epoch 371, x: -0.000717
# epoch 372, x: -0.000714
# epoch 373, x: -0.000711
# epoch 374, x: -0.000709
# epoch 375, x: -0.000706
# epoch 376, x: -0.000703
# epoch 377, x: -0.000700
# epoch 378, x: -0.000697
# epoch 379, x: -0.000695
# epoch 380, x: -0.000692
# epoch 381, x: -0.000689
# epoch 382, x: -0.000687
# epoch 383, x: -0.000684
# epoch 384, x: -0.000682
# epoch 385, x: -0.000679
# epoch 386, x: -0.000677
# epoch 387, x: -0.000674
# epoch 388, x: -0.000672
# epoch 389, x: -0.000669
# epoch 390, x: -0.000667
# epoch 391, x: -0.000664
# epoch 392, x: -0.000662
# epoch 393, x: -0.000660
# epoch 394, x: -0.000657
# epoch 395, x: -0.000655
# epoch 396, x: -0.000653
# epoch 397, x: -0.000651
# epoch 398, x: -0.000648
# epoch 399, x: -0.000646
# epoch 400, x: -0.000644
# epoch 401, x: -0.000642
# epoch 402, x: -0.000640
# epoch 403, x: -0.000638
# epoch 404, x: -0.000636
# epoch 405, x: -0.000634
# epoch 406, x: -0.000632
# epoch 407, x: -0.000630
# epoch 408, x: -0.000628
# epoch 409, x: -0.000626
# epoch 410, x: -0.000624
# epoch 411, x: -0.000622
# epoch 412, x: -0.000620
# epoch 413, x: -0.000618
# epoch 414, x: -0.000616
# epoch 415, x: -0.000614
# epoch 416, x: -0.000612
# epoch 417, x: -0.000610
# epoch 418, x: -0.000609
# epoch 419, x: -0.000607
# epoch 420, x: -0.000605
# epoch 421, x: -0.000603
# epoch 422, x: -0.000602
# epoch 423, x: -0.000600
# epoch 424, x: -0.000598
# epoch 425, x: -0.000596
# epoch 426, x: -0.000595
# epoch 427, x: -0.000593
# epoch 428, x: -0.000591
# epoch 429, x: -0.000590
# epoch 430, x: -0.000588
# epoch 431, x: -0.000586
# epoch 432, x: -0.000585
# epoch 433, x: -0.000583
# epoch 434, x: -0.000582
# epoch 435, x: -0.000580
# epoch 436, x: -0.000578
# epoch 437, x: -0.000577
# epoch 438, x: -0.000575
# epoch 439, x: -0.000574
# epoch 440, x: -0.000572
# epoch 441, x: -0.000571
# epoch 442, x: -0.000569
# epoch 443, x: -0.000568
# epoch 444, x: -0.000566
# epoch 445, x: -0.000565
# epoch 446, x: -0.000564
# epoch 447, x: -0.000562
# epoch 448, x: -0.000561
# epoch 449, x: -0.000559
# epoch 450, x: -0.000558
# epoch 451, x: -0.000556
# epoch 452, x: -0.000555
# epoch 453, x: -0.000554
# epoch 454, x: -0.000552
# epoch 455, x: -0.000551
# epoch 456, x: -0.000550
# epoch 457, x: -0.000548
# epoch 458, x: -0.000547
# epoch 459, x: -0.000546
# epoch 460, x: -0.000544
# epoch 461, x: -0.000543
# epoch 462, x: -0.000542
# epoch 463, x: -0.000541
# epoch 464, x: -0.000539
# epoch 465, x: -0.000538
# epoch 466, x: -0.000537
# epoch 467, x: -0.000536
# epoch 468, x: -0.000534
# epoch 469, x: -0.000533
# epoch 470, x: -0.000532
# epoch 471, x: -0.000531
# epoch 472, x: -0.000530
# epoch 473, x: -0.000528
# epoch 474, x: -0.000527
# epoch 475, x: -0.000526
# epoch 476, x: -0.000525
# epoch 477, x: -0.000524
# epoch 478, x: -0.000523
# epoch 479, x: -0.000521
# epoch 480, x: -0.000520
# epoch 481, x: -0.000519
# epoch 482, x: -0.000518
# epoch 483, x: -0.000517
# epoch 484, x: -0.000516
# epoch 485, x: -0.000515
# epoch 486, x: -0.000514
# epoch 487, x: -0.000512
# epoch 488, x: -0.000511
# epoch 489, x: -0.000510
# epoch 490, x: -0.000509
# epoch 491, x: -0.000508
# epoch 492, x: -0.000507
# epoch 493, x: -0.000506
# epoch 494, x: -0.000505
# epoch 495, x: -0.000504
# epoch 496, x: -0.000503
# epoch 497, x: -0.000502
# epoch 498, x: -0.000501
# epoch 499, x: -0.000500
# epoch 500, x: -0.000499
# epoch 501, x: -0.000498
# epoch 502, x: -0.000497
# epoch 503, x: -0.000496
# epoch 504, x: -0.000495
# epoch 505, x: -0.000494
# epoch 506, x: -0.000493
# epoch 507, x: -0.000492
# epoch 508, x: -0.000491
# epoch 509, x: -0.000490
# epoch 510, x: -0.000489
# epoch 511, x: -0.000488
# epoch 512, x: -0.000487
# epoch 513, x: -0.000487
# epoch 514, x: -0.000486
# epoch 515, x: -0.000485
# epoch 516, x: -0.000484
# epoch 517, x: -0.000483
# epoch 518, x: -0.000482
# epoch 519, x: -0.000481
# epoch 520, x: -0.000480
# epoch 521, x: -0.000479
# epoch 522, x: -0.000478
# epoch 523, x: -0.000478
# epoch 524, x: -0.000477
# epoch 525, x: -0.000476
# epoch 526, x: -0.000475
# epoch 527, x: -0.000474
# epoch 528, x: -0.000473
# epoch 529, x: -0.000472
# epoch 530, x: -0.000472
# epoch 531, x: -0.000471
# epoch 532, x: -0.000470
# epoch 533, x: -0.000469
# epoch 534, x: -0.000468
# epoch 535, x: -0.000467
# epoch 536, x: -0.000467
# epoch 537, x: -0.000466
# epoch 538, x: -0.000465
# epoch 539, x: -0.000464
# epoch 540, x: -0.000463
# epoch 541, x: -0.000463
# epoch 542, x: -0.000462
# epoch 543, x: -0.000461
# epoch 544, x: -0.000460
# epoch 545, x: -0.000459
# epoch 546, x: -0.000459
# epoch 547, x: -0.000458
# epoch 548, x: -0.000457
# epoch 549, x: -0.000456
# epoch 550, x: -0.000456
# epoch 551, x: -0.000455
# epoch 552, x: -0.000454
# epoch 553, x: -0.000453
# epoch 554, x: -0.000453
# epoch 555, x: -0.000452
# epoch 556, x: -0.000451
# epoch 557, x: -0.000450
# epoch 558, x: -0.000450
# epoch 559, x: -0.000449
# epoch 560, x: -0.000448
# epoch 561, x: -0.000447
# epoch 562, x: -0.000447
# epoch 563, x: -0.000446
# epoch 564, x: -0.000445
# epoch 565, x: -0.000445
# epoch 566, x: -0.000444
# epoch 567, x: -0.000443
# epoch 568, x: -0.000443
# epoch 569, x: -0.000442
# epoch 570, x: -0.000441
# epoch 571, x: -0.000440
# epoch 572, x: -0.000440
# epoch 573, x: -0.000439
# epoch 574, x: -0.000438
# epoch 575, x: -0.000438
# epoch 576, x: -0.000437
# epoch 577, x: -0.000436
# epoch 578, x: -0.000436
# epoch 579, x: -0.000435
# epoch 580, x: -0.000434
# epoch 581, x: -0.000434
# epoch 582, x: -0.000433
# epoch 583, x: -0.000432
# epoch 584, x: -0.000432
# epoch 585, x: -0.000431
# epoch 586, x: -0.000431
# epoch 587, x: -0.000430
# epoch 588, x: -0.000429
# epoch 589, x: -0.000429
# epoch 590, x: -0.000428
# epoch 591, x: -0.000427
# epoch 592, x: -0.000427
# epoch 593, x: -0.000426
# epoch 594, x: -0.000425
# epoch 595, x: -0.000425
# epoch 596, x: -0.000424
# epoch 597, x: -0.000424
# epoch 598, x: -0.000423
# epoch 599, x: -0.000422
# epoch 600, x: -0.000422
# epoch 601, x: -0.000421
# epoch 602, x: -0.000421
# epoch 603, x: -0.000420
# epoch 604, x: -0.000419
# epoch 605, x: -0.000419
# epoch 606, x: -0.000418
# epoch 607, x: -0.000418
# epoch 608, x: -0.000417
# epoch 609, x: -0.000417
# epoch 610, x: -0.000416
# epoch 611, x: -0.000415
# epoch 612, x: -0.000415
# epoch 613, x: -0.000414
# epoch 614, x: -0.000414
# epoch 615, x: -0.000413
# epoch 616, x: -0.000413
# epoch 617, x: -0.000412
# epoch 618, x: -0.000411
# epoch 619, x: -0.000411
# epoch 620, x: -0.000410
# epoch 621, x: -0.000410
# epoch 622, x: -0.000409
# epoch 623, x: -0.000409
# epoch 624, x: -0.000408
# epoch 625, x: -0.000408
# epoch 626, x: -0.000407
# epoch 627, x: -0.000406
# epoch 628, x: -0.000406
# epoch 629, x: -0.000405
# epoch 630, x: -0.000405
# epoch 631, x: -0.000404
# epoch 632, x: -0.000404
# epoch 633, x: -0.000403
# epoch 634, x: -0.000403
# epoch 635, x: -0.000402
# epoch 636, x: -0.000402
# epoch 637, x: -0.000401
# epoch 638, x: -0.000401
# epoch 639, x: -0.000400
# epoch 640, x: -0.000400
# epoch 641, x: -0.000399
# epoch 642, x: -0.000399
# epoch 643, x: -0.000398
# epoch 644, x: -0.000398
# epoch 645, x: -0.000397
# epoch 646, x: -0.000397
# epoch 647, x: -0.000396
# epoch 648, x: -0.000396
# epoch 649, x: -0.000395
# epoch 650, x: -0.000395
# epoch 651, x: -0.000394
# epoch 652, x: -0.000394
# epoch 653, x: -0.000393
# epoch 654, x: -0.000393
# epoch 655, x: -0.000392
# epoch 656, x: -0.000392
# epoch 657, x: -0.000391
# epoch 658, x: -0.000391
# epoch 659, x: -0.000390
# epoch 660, x: -0.000390
# epoch 661, x: -0.000389
# epoch 662, x: -0.000389
# epoch 663, x: -0.000388
# epoch 664, x: -0.000388
# epoch 665, x: -0.000387
# epoch 666, x: -0.000387
# epoch 667, x: -0.000387
# epoch 668, x: -0.000386
# epoch 669, x: -0.000386
# epoch 670, x: -0.000385
# epoch 671, x: -0.000385
# epoch 672, x: -0.000384
# epoch 673, x: -0.000384
# epoch 674, x: -0.000383
# epoch 675, x: -0.000383
# epoch 676, x: -0.000382
# epoch 677, x: -0.000382
# epoch 678, x: -0.000382
# epoch 679, x: -0.000381
# epoch 680, x: -0.000381
# epoch 681, x: -0.000380
# epoch 682, x: -0.000380
# epoch 683, x: -0.000379
# epoch 684, x: -0.000379
# epoch 685, x: -0.000378
# epoch 686, x: -0.000378
# epoch 687, x: -0.000378
# epoch 688, x: -0.000377
# epoch 689, x: -0.000377
# epoch 690, x: -0.000376
# epoch 691, x: -0.000376
# epoch 692, x: -0.000375
# epoch 693, x: -0.000375
# epoch 694, x: -0.000375
# epoch 695, x: -0.000374
# epoch 696, x: -0.000374
# epoch 697, x: -0.000373
# epoch 698, x: -0.000373
# epoch 699, x: -0.000373
# epoch 700, x: -0.000372
# epoch 701, x: -0.000372
# epoch 702, x: -0.000371
# epoch 703, x: -0.000371
# epoch 704, x: -0.000370
# epoch 705, x: -0.000370
# epoch 706, x: -0.000370
# epoch 707, x: -0.000369
# epoch 708, x: -0.000369
# epoch 709, x: -0.000368
# epoch 710, x: -0.000368
# epoch 711, x: -0.000368
# epoch 712, x: -0.000367
# epoch 713, x: -0.000367
# epoch 714, x: -0.000366
# epoch 715, x: -0.000366
# epoch 716, x: -0.000366
# epoch 717, x: -0.000365
# epoch 718, x: -0.000365
# epoch 719, x: -0.000364
# epoch 720, x: -0.000364
# epoch 721, x: -0.000364
# epoch 722, x: -0.000363
# epoch 723, x: -0.000363
# epoch 724, x: -0.000363
# epoch 725, x: -0.000362
# epoch 726, x: -0.000362
# epoch 727, x: -0.000361
# epoch 728, x: -0.000361
# epoch 729, x: -0.000361
# epoch 730, x: -0.000360
# epoch 731, x: -0.000360
# epoch 732, x: -0.000360
# epoch 733, x: -0.000359
# epoch 734, x: -0.000359
# epoch 735, x: -0.000358
# epoch 736, x: -0.000358
# epoch 737, x: -0.000358
# epoch 738, x: -0.000357
# epoch 739, x: -0.000357
# epoch 740, x: -0.000357
# epoch 741, x: -0.000356
# epoch 742, x: -0.000356
# epoch 743, x: -0.000356
# epoch 744, x: -0.000355
# epoch 745, x: -0.000355
# epoch 746, x: -0.000354
# epoch 747, x: -0.000354
# epoch 748, x: -0.000354
# epoch 749, x: -0.000353
# epoch 750, x: -0.000353
# epoch 751, x: -0.000353
# epoch 752, x: -0.000352
# epoch 753, x: -0.000352
# epoch 754, x: -0.000352
# epoch 755, x: -0.000351
# epoch 756, x: -0.000351
# epoch 757, x: -0.000351
# epoch 758, x: -0.000350
# epoch 759, x: -0.000350
# epoch 760, x: -0.000350
# epoch 761, x: -0.000349
# epoch 762, x: -0.000349
# epoch 763, x: -0.000349
# epoch 764, x: -0.000348
# epoch 765, x: -0.000348
# epoch 766, x: -0.000348
# epoch 767, x: -0.000347
# epoch 768, x: -0.000347
# epoch 769, x: -0.000347
# epoch 770, x: -0.000346
# epoch 771, x: -0.000346
# epoch 772, x: -0.000346
# epoch 773, x: -0.000345
# epoch 774, x: -0.000345
# epoch 775, x: -0.000345
# epoch 776, x: -0.000344
# epoch 777, x: -0.000344
# epoch 778, x: -0.000344
# epoch 779, x: -0.000343
# epoch 780, x: -0.000343
# epoch 781, x: -0.000343
# epoch 782, x: -0.000342
# epoch 783, x: -0.000342
# epoch 784, x: -0.000342
# epoch 785, x: -0.000341
# epoch 786, x: -0.000341
# epoch 787, x: -0.000341
# epoch 788, x: -0.000340
# epoch 789, x: -0.000340
# epoch 790, x: -0.000340
# epoch 791, x: -0.000339
# epoch 792, x: -0.000339
# epoch 793, x: -0.000339
# epoch 794, x: -0.000338
# epoch 795, x: -0.000338
# epoch 796, x: -0.000338
# epoch 797, x: -0.000338
# epoch 798, x: -0.000337
# epoch 799, x: -0.000337
# epoch 800, x: -0.000337
# epoch 801, x: -0.000336
# epoch 802, x: -0.000336
# epoch 803, x: -0.000336
# epoch 804, x: -0.000335
# epoch 805, x: -0.000335
# epoch 806, x: -0.000335
# epoch 807, x: -0.000335
# epoch 808, x: -0.000334
# epoch 809, x: -0.000334
# epoch 810, x: -0.000334
# epoch 811, x: -0.000333
# epoch 812, x: -0.000333
# epoch 813, x: -0.000333
# epoch 814, x: -0.000332
# epoch 815, x: -0.000332
# epoch 816, x: -0.000332
# epoch 817, x: -0.000332
# epoch 818, x: -0.000331
# epoch 819, x: -0.000331
# epoch 820, x: -0.000331
# epoch 821, x: -0.000330
# epoch 822, x: -0.000330
# epoch 823, x: -0.000330
# epoch 824, x: -0.000330
# epoch 825, x: -0.000329
# epoch 826, x: -0.000329
# epoch 827, x: -0.000329
# epoch 828, x: -0.000328
# epoch 829, x: -0.000328
# epoch 830, x: -0.000328
# epoch 831, x: -0.000328
# epoch 832, x: -0.000327
# epoch 833, x: -0.000327
# epoch 834, x: -0.000327
# epoch 835, x: -0.000326
# epoch 836, x: -0.000326
# epoch 837, x: -0.000326
# epoch 838, x: -0.000326
# epoch 839, x: -0.000325
# epoch 840, x: -0.000325
# epoch 841, x: -0.000325
# epoch 842, x: -0.000324
# epoch 843, x: -0.000324
# epoch 844, x: -0.000324
# epoch 845, x: -0.000324
# epoch 846, x: -0.000323
# epoch 847, x: -0.000323
# epoch 848, x: -0.000323
# epoch 849, x: -0.000323
# epoch 850, x: -0.000322
# epoch 851, x: -0.000322
# epoch 852, x: -0.000322
# epoch 853, x: -0.000322
# epoch 854, x: -0.000321
# epoch 855, x: -0.000321
# epoch 856, x: -0.000321
# epoch 857, x: -0.000320
# epoch 858, x: -0.000320
# epoch 859, x: -0.000320
# epoch 860, x: -0.000320
# epoch 861, x: -0.000319
# epoch 862, x: -0.000319
# epoch 863, x: -0.000319
# epoch 864, x: -0.000319
# epoch 865, x: -0.000318
# epoch 866, x: -0.000318
# epoch 867, x: -0.000318
# epoch 868, x: -0.000318
# epoch 869, x: -0.000317
# epoch 870, x: -0.000317
# epoch 871, x: -0.000317
# epoch 872, x: -0.000317
# epoch 873, x: -0.000316
# epoch 874, x: -0.000316
# epoch 875, x: -0.000316
# epoch 876, x: -0.000316
# epoch 877, x: -0.000315
# epoch 878, x: -0.000315
# epoch 879, x: -0.000315
# epoch 880, x: -0.000315
# epoch 881, x: -0.000314
# epoch 882, x: -0.000314
# epoch 883, x: -0.000314
# epoch 884, x: -0.000314
# epoch 885, x: -0.000313
# epoch 886, x: -0.000313
# epoch 887, x: -0.000313
# epoch 888, x: -0.000313
# epoch 889, x: -0.000312
# epoch 890, x: -0.000312
# epoch 891, x: -0.000312
# epoch 892, x: -0.000312
# epoch 893, x: -0.000311
# epoch 894, x: -0.000311
# epoch 895, x: -0.000311
# epoch 896, x: -0.000311
# epoch 897, x: -0.000310
# epoch 898, x: -0.000310
# epoch 899, x: -0.000310
# epoch 900, x: -0.000310
# epoch 901, x: -0.000309
# epoch 902, x: -0.000309
# epoch 903, x: -0.000309
# epoch 904, x: -0.000309
# epoch 905, x: -0.000309
# epoch 906, x: -0.000308
# epoch 907, x: -0.000308
# epoch 908, x: -0.000308
# epoch 909, x: -0.000308
# epoch 910, x: -0.000307
# epoch 911, x: -0.000307
# epoch 912, x: -0.000307
# epoch 913, x: -0.000307
# epoch 914, x: -0.000306
# epoch 915, x: -0.000306
# epoch 916, x: -0.000306
# epoch 917, x: -0.000306
# epoch 918, x: -0.000305
# epoch 919, x: -0.000305
# epoch 920, x: -0.000305
# epoch 921, x: -0.000305
# epoch 922, x: -0.000305
# epoch 923, x: -0.000304
# epoch 924, x: -0.000304
# epoch 925, x: -0.000304
# epoch 926, x: -0.000304
# epoch 927, x: -0.000303
# epoch 928, x: -0.000303
# epoch 929, x: -0.000303
# epoch 930, x: -0.000303
# epoch 931, x: -0.000303
# epoch 932, x: -0.000302
# epoch 933, x: -0.000302
# epoch 934, x: -0.000302
# epoch 935, x: -0.000302
# epoch 936, x: -0.000301
# epoch 937, x: -0.000301
# epoch 938, x: -0.000301
# epoch 939, x: -0.000301
# epoch 940, x: -0.000301
# epoch 941, x: -0.000300
# epoch 942, x: -0.000300
# epoch 943, x: -0.000300
# epoch 944, x: -0.000300
# epoch 945, x: -0.000300
# epoch 946, x: -0.000299
# epoch 947, x: -0.000299
# epoch 948, x: -0.000299
# epoch 949, x: -0.000299
# epoch 950, x: -0.000298
# epoch 951, x: -0.000298
# epoch 952, x: -0.000298
# epoch 953, x: -0.000298
# epoch 954, x: -0.000298
# epoch 955, x: -0.000297
# epoch 956, x: -0.000297
# epoch 957, x: -0.000297
# epoch 958, x: -0.000297
# epoch 959, x: -0.000297
# epoch 960, x: -0.000296
# epoch 961, x: -0.000296
# epoch 962, x: -0.000296
# epoch 963, x: -0.000296
# epoch 964, x: -0.000296
# epoch 965, x: -0.000295
# epoch 966, x: -0.000295
# epoch 967, x: -0.000295
# epoch 968, x: -0.000295
# epoch 969, x: -0.000294
# epoch 970, x: -0.000294
# epoch 971, x: -0.000294
# epoch 972, x: -0.000294
# epoch 973, x: -0.000294
# epoch 974, x: -0.000293
# epoch 975, x: -0.000293
# epoch 976, x: -0.000293
# epoch 977, x: -0.000293
# epoch 978, x: -0.000293
# epoch 979, x: -0.000292
# epoch 980, x: -0.000292
# epoch 981, x: -0.000292
# epoch 982, x: -0.000292
# epoch 983, x: -0.000292
# epoch 984, x: -0.000291
# epoch 985, x: -0.000291
# epoch 986, x: -0.000291
# epoch 987, x: -0.000291
# epoch 988, x: -0.000291
# epoch 989, x: -0.000290
# epoch 990, x: -0.000290
# epoch 991, x: -0.000290
# epoch 992, x: -0.000290
# epoch 993, x: -0.000290
# epoch 994, x: -0.000289
# epoch 995, x: -0.000289
# epoch 996, x: -0.000289
# epoch 997, x: -0.000289
# epoch 998, x: -0.000289
# epoch 999, x: -0.000289
# epoch 1000, x: -0.000289

# %%
def is_equal(a, b, accuracy):
    return abs(a-b) <= accuracy

# %%
# # gradient descent algorithm with adadelta
def adadelta(objective, derivative, bounds, n_iter, patience, accuracy, minima, rho, ep=1e-3):
	prev_solution = (-1, -1)
	converged = True
	# track all solutions
	solutions = list()
	# generate an initial point
	solution = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])
	# list of the average square gradients for each variable
	sq_grad_avg = [0.0 for _ in range(bounds.shape[0])]
	# list of the average parameter updates
	sq_para_avg = [0.0 for _ in range(bounds.shape[0])]
	# run the gradient descent
	for it in range(n_iter):
		# calculate gradient
		gradient = derivative(solution[0], solution[1])
		# update the average of the squared partial derivatives
		for i in range(gradient.shape[0]):
			# calculate the squared gradient
			sg = gradient[i]**2.0
			# update the moving average of the squared gradient
			sq_grad_avg[i] = (sq_grad_avg[i] * rho) + (sg * (1.0-rho))
		# build solution
		new_solution = list()
		for i in range(solution.shape[0]):
			# calculate the step size for this variable
			alpha = (ep + sqrt(sq_para_avg[i])) / (ep + sqrt(sq_grad_avg[i]))
			# calculate the change
			change = alpha * gradient[i]
			# update the moving average of squared parameter changes
			sq_para_avg[i] = (sq_para_avg[i] * rho) + (change**2.0 * (1.0-rho))
			# calculate the new position in this variable
			value = solution[i] - change
			# store this variable
			new_solution.append(value)
		# store the new solution
		solution = asarray(new_solution)
		solutions.append(solution)
		# evaluate candidate point
		solution_eval = objective(solution[0], solution[1])
		# report progress
		# print('&gt;%d f(%s) = %.5f' % (it, solution, solution_eval))
		if (it == n_iter - patience):
			prev_solution = solution
		if (it > n_iter - patience):
			if (is_equal(solution, prev_solution, accuracy) == False):
				converged = False
				break
			prev_solution = solution
			
	return solutions, converged, is_equal(prev_solution, minima, accuracy)


def mine_gd(objective, derivative, bounds, n_iter, patience, accuracy, minima, rho, ep=1e-3):
	# track all solutions
	solutions = list()
	# generate an initial point
	solution = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])
	# list of the average square gradients for each variable
	sq_grad_avg = [0.0 for _ in range(bounds.shape[0])]
	# list of the average parameter updates
	sq_para_avg = [0.0 for _ in range(bounds.shape[0])]
	# run the gradient descent
	for it in range(n_iter):
		# calculate gradient
		gradient = derivative(solution[0], solution[1])
		# update the average of the squared partial derivatives
		# for i in range(gradient.shape[0]):
		# 	# calculate the squared gradient
		# 	sg = gradient[i]**2.0
		# 	# update the moving average of the squared gradient
		# 	sq_grad_avg[i] = (sq_grad_avg[i] * rho) + (sg * (1.0-rho))
		# build solution
		new_solution = list()
		for i in range(solution.shape[0]):
			# calculate the step size for this variable
			# alpha = (ep + sqrt(sq_para_avg[i])) / (ep + sqrt(sq_grad_avg[i]))
			# calculate the change
			change = (abs(gradient[i]) * abs(gradient[i]) * gradient[i]) / ((1 + gradient[i]**2)**2)
			# update the moving average of squared parameter changes
			# sq_para_avg[i] = (sq_para_avg[i] * rho) + (change**2.0 * (1.0-rho))
			# calculate the new position in this variable
			value = solution[i] - change
			# store this variable
			new_solution.append(value)
		# store the new solution
		solution = asarray(new_solution)
		solutions.append(solution)
		# evaluate candidate point
		solution_eval = objective(solution[0], solution[1])
		# report progress
		# print('&gt;%d f(%s) = %.5f' % (it, solution, solution_eval))
	return solutions

# %%
from math import sqrt, pi
from numpy import asarray
from numpy import arange, cos, sin, exp
from numpy.random import rand
from numpy.random import seed
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import math

# %%
from test_functions import BOHACHEVSKY, EASOM, MCCORMICK

class TestFunctions(Enum):
    BOHACHEVSKY = BOHACHEVSKY
    EASOM = EASOM
    MCCORMICK = MCCORMICK

# %%
def plot2d(solutions, bounds, objective):
    xaxis = arange(bounds[0,0], bounds[0,1], 0.1)
    yaxis = arange(bounds[1,0], bounds[1,1], 0.1)
    x, y = meshgrid(xaxis, yaxis)
    results = objective(x, y)
    pyplot.contourf(x, y, results, levels=50, cmap='jet')
    solutions = asarray(solutions)
    pyplot.plot(solutions[:, 0], solutions[:, 1], '.-', color='w')
    pyplot.show()

# %%
seeds = [1, 2]
n_iter = 10000
patience = 500
accuracy = 1e-5

# %%
for curr_fun in iter(TestFunctions):
    for curr_seed in seeds:
        seed(curr_seed)
        print(f"Using function: {curr_fun.name} with seed: {curr_seed}")
        bounds = asarray([[curr_fun.value.x1_bounds[0], curr_fun.value.x1_bounds[1]], [curr_fun.value.x2_bounds[0], curr_fun.value.x2_bounds[1]]])
        rho = 0.9
        solutions, converged, is_minima = adadelta(curr_fun.value.z, curr_fun.value.df, bounds, n_iter, patience, accuracy, minima, rho)
        print(converged, is_minima)
        # plot2d(solutions, bounds, curr_fun.value.z)
